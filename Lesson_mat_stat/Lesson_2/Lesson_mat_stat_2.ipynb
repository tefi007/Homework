# %% [markdown]
# Задача 1
#
# Контрольная работа состоит из пяти вопросов. На каждый вопрос приведено четыре варианта ответа, один из которых правильный. Составьте закон распределения числа правильных ответов при простом угадывании. Найдите M(X), D(X).

# %% [markdown]
# p = 1/4     # Вероятность правильного ответа на один вопрос
# n = 5       # Количество вопросов
# Всего комбинаций 32
# Расчитываем вероятности по формуле
# C = n! / k! * (n-k)!
# Расчитываем распределение по формуле
# P = C * p^k * q^(n-k)
# прав ответы  (кол-во комбинаций) - вероятность    - распределение
# 0                   (1)          - 0,03125        - 0,2373
# 1                   (5)          - 0,15625        - 0,3955
# 2                   (10)         - 0,3125         - 0,2637
# 3                   (10)         - 0,3125         - 0,088
# 4                   (5)          - 0,15625        - 0,0146
# 5                   (1)          - 0,031125       - 0,000977
#
# m(x) = 5 * 0.25 = 1.25
# d(x) = 5 * 0.25 * 0.75 = 0.9375

# %% [markdown]
# Задача 2
#
# Пользователь получает в среднем 10 писем со спамом на свой почтовый ящик за сутки. Найти число N, такое, что с вероятностью 0.95 пользователь получит не более N писем со спамом за текущий день.

# %%
from math import factorial, exp
# формула P = (l^m/m!) * e^(-l)
l = 10  # лямбда

for m in range (1,20):
    P =  l**m / factorial(m) * exp(-l)
    print(m, P)
что-то пошло не так и ответ не получается
# Out:
# 1 0.00045399929762484856
# 2 0.0022699964881242427
# 3 0.007566654960414142
# 4 0.018916637401035358
# 5 0.037833274802070715
# 6 0.06305545800345119
# 7 0.09007922571921598
# 8 0.11259903214901998
# 9 0.1251100357211333
# 10 0.1251100357211333
# 11 0.1137363961101212
# 12 0.09478033009176765
# 13 0.07290794622443666
# 14 0.05207710444602618
# 15 0.03471806963068413
# 16 0.021698793519177577
# 17 0.012763996187751515
# 18 0.007091108993195287
# 19 0.0037321626279975197

# %% [markdown]
# Задача 3
#
# Производятся выстрелы по мишени. Вероятность попадания в мишень при одном выстреле равна 0.01. Сколько выстрелов нужно сделать чтобы быть уверенным с вероятностью 0.9, что хотя бы 6 раз будет совершено попадание?
# Подсказка. 1) "Вероятность попасть k раз при n выстрелах" - на какое распределение это похоже? 2) А если нам нужна вероятность P(X >= k), а не P(X = k)? 3) Здесь предстоит немножко покодить.

# %%
1) это похоже на биномиальное распределение
решить не смогла

# %%
import numpy as np
import pandas as pd
pd.options.display.max_columns = 500
import matplotlib.pyplot as plt
#matplotlib inline
import seaborn as sns

# %%
# пути расположения выборок
path_train = '/home/tefi/Homework/Sport/train.csv'
path_test = '/home/tefi/Homework/Sport/test.csv'

# %%
# загрузка данных из файлов в соответствующие переменные
train = pd.read_csv(path_train)
test = pd.read_csv(path_test)

# %%
train.head(2)
# Out:
#    ID_code  target    var_0   var_1    var_2  var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.093  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.389  12.3622  7.0433  5.6208
#
#      var_7   var_8   var_9  var_10  var_11   var_12  var_13  var_14   var_15  \
# 0  18.6266 -4.9200  5.7470  2.9252  3.1821  14.0137  0.5745  8.7989  14.5691
# 1  16.5338  3.1468  8.0851 -0.4032  8.0585  14.0239  8.4135  5.4345  13.7003
#
#     var_16   var_17  var_18   var_19   var_20   var_21  var_22  var_23  \
# 0   5.7487  -7.2393   4.284  30.7133  10.5350  16.2191  2.5791  2.4716
# 1  13.8275 -15.5849   7.800  28.5708   3.4287   2.7407  8.5524  3.3716
#
#     var_24   var_25   var_26  var_27  var_28  var_29  var_30   var_31  var_32  \
# 0  14.3831  13.4325  -5.1488 -0.4073  4.9306  5.9965 -0.3085  12.9041 -3.8766
# 1   6.9779  13.8910 -11.7684 -2.5586  5.0464  0.5481 -9.2987   7.8755  1.2859
#
# ...

# %%
test.head(2)
# Out:
#   ID_code    var_0   var_1    var_2   var_3    var_4   var_5   var_6    var_7  \
# 0  test_0  11.0656  7.7798  12.9536  9.4292  11.4327 -2.3805  5.8493  18.2675
# 1  test_1   8.5304  1.2543  11.3047  5.1858   9.1974 -4.0117  6.0196  18.6316
#
#     var_8   var_9  var_10  var_11   var_12  var_13  var_14   var_15  var_16  \
# 0  2.1337  8.8100 -2.0248 -4.3554  13.9696  0.3458  7.5408  14.5001  7.7028
# 1 -4.4131  5.9739 -1.3809 -0.3310  14.1129  2.5667  5.4988  14.1853  7.0196
#
#     var_17   var_18   var_19   var_20   var_21  var_22  var_23   var_24  \
# 0 -19.0919  15.5806  16.1763   3.7088  18.8064  1.5899  3.0654   6.4509
# 1   4.6564  29.1609   0.0910  12.1469   3.1389  5.2578  2.4228  16.2064
#
#     var_25  var_26  var_27  var_28  var_29   var_30   var_31  var_32   var_33  \
# 0  14.1192 -9.4902 -2.1917  5.7107  3.7864  -1.7981   9.2645  2.0657  12.7753
# 1  13.5023 -5.2341 -3.6648  5.7080  2.9965 -10.4720  11.4938 -0.9660  15.3445
#
# ...

# %%
train_data = train.copy()
train_data = train_data.drop(['target'], axis ='columns')  # тренировочные данные без целевой переменной
train_target = train.copy()
train_target = train['target']                             # целевая переменная для тренировочных данных
test_data = test.copy()                                            # тестовые данные

# %%
# кол-во столбцов на test и train совпадают 
train_data.shape
# Out:
# (200000, 201)

# %%
test_data.shape
# Out:
# (200000, 201)

# %%
train_data.dtypes.value_counts()
# Out:
# float64    200
# object       1
# dtype: int64

# %%
test_data.dtypes.value_counts()
# Out:
# float64    200
# object       1
# dtype: int64

# %%
train_data.dtypes
# Out:
# ID_code     object
# var_0      float64
# var_1      float64
# var_2      float64
# var_3      float64
#             ...
# var_195    float64
# var_196    float64
# var_197    float64
# var_198    float64
# var_199    float64
# Length: 201, dtype: object

# %%
test_data.dtypes
# Out:
# ID_code     object
# var_0      float64
# var_1      float64
# var_2      float64
# var_3      float64
#             ...
# var_195    float64
# var_196    float64
# var_197    float64
# var_198    float64
# var_199    float64
# Length: 201, dtype: object

# %%
# пропусков нет
train_data.describe()
# Out:
#                var_0          var_1          var_2          var_3  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean       10.679914      -1.627622      10.715192       6.796529
# std         3.040051       4.050044       2.640894       2.043319
# min         0.408400     -15.043400       2.117100      -0.040200
# 25%         8.453850      -4.740025       8.722475       5.254075
# 50%        10.524750      -1.608050      10.580000       6.825000
# 75%        12.758200       1.358625      12.516700       8.324100
# max        20.315000      10.376800      19.353000      13.188300
#
#                var_4          var_5          var_6          var_7  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean       11.078333      -5.065317       5.408949      16.545850
# std         1.623150       7.863267       0.866607       3.418076
# min         5.074800     -32.562600       2.347300       5.349700
# ...

# %%
test_data.describe()
# Out:
#                var_0          var_1          var_2          var_3  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean       10.658737      -1.624244      10.707452       6.788214
# std         3.036716       4.040509       2.633888       2.052724
# min         0.188700     -15.043400       2.355200      -0.022400
# 25%         8.442975      -4.700125       8.735600       5.230500
# 50%        10.513800      -1.590500      10.560700       6.822350
# 75%        12.739600       1.343400      12.495025       8.327600
# max        22.323400       9.385100      18.714100      13.142000
#
#                var_4          var_5          var_6          var_7  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean       11.076399      -5.050558       5.415164      16.529143
# std         1.616456       7.869293       0.864686       3.424482
# min         5.484400     -27.767000       2.216400       5.713700
# ...

# %%
train_data.isnull().sum()
# Out:
# ID_code    0
# var_0      0
# var_1      0
# var_2      0
# var_3      0
#           ..
# var_195    0
# var_196    0
# var_197    0
# var_198    0
# var_199    0
# Length: 201, dtype: int64

# %%
train_data['ID_code'].value_counts()
# Out:
# train_67662     1
# train_121275    1
# train_15735     1
# train_29995     1
# train_178891    1
#                ..
# train_196022    1
# train_86474     1
# train_29892     1
# train_31612     1
# train_28134     1
# Name: ID_code, Length: 200000, dtype: int64

# %%
# пропусков нет
train_target.isnull().sum()
# Out:
# 0

# %%
# выборка несбалансированная
train_target.value_counts()
# Out:
# 0    179902
# 1     20098
# Name: target, dtype: int64

# %%
TARGET_NAME = 'target'
train_data_t = train_data.copy()
train_data_t[TARGET_NAME] = train[TARGET_NAME] 
train_data_t

corr_with_target = train_data_t.corr().iloc[:-1, -1].sort_values(ascending=False)

plt.figure(figsize=(15, 32))

sns.barplot(x=corr_with_target.values, y=corr_with_target.index)
#sns.barplot(x=train.values, y=train.index)

plt.title('Correlation with target variable')
plt.show()

# %%
# графики распределения плотности
plt.figure(figsize = ([15,30]))

plt.subplots_adjust(wspace=0.4, hspace=0.35)

plt.subplot(8,4,1)
sns.kdeplot(train_data['var_0'], shade=True, color="g")
plt.title('var_0')
plt.xlabel('кол-во')
plt.ylabel('var_0')

plt.subplot(8,4,2)
sns.kdeplot(train_data['var_1'], shade=True, color="g")
plt.title('var_1')
plt.xlabel('кол-во')
plt.ylabel('var_1')

plt.subplot(8,4,3)
sns.kdeplot(train_data['var_2'], shade=True, color="g")
plt.title('var_2')
plt.xlabel('кол-во')
plt.ylabel('var_2')

plt.subplot(8,4,4)
sns.kdeplot(train_data['var_5'], shade=True, color="g")
plt.title('var_5')
plt.xlabel('кол-во')
plt.ylabel('var_5')

plt.subplot(8,4,5)
sns.kdeplot(train_data['var_9'], shade=True, color="g")
plt.title('var_9')
plt.xlabel('кол-во')
plt.ylabel('var_9')

plt.subplot(8,4,6)
sns.kdeplot(train_data['var_10'], shade=True, color="g")
plt.title('var_10')
plt.xlabel('кол-во')
plt.ylabel('var_10')

plt.subplot(8,4,7)
sns.kdeplot(train_data['var_13'], shade=True, color="g")
plt.title('var_13')
plt.xlabel('кол-во')
plt.ylabel('var_13')

plt.subplot(8,4,8)
sns.kdeplot(train_data['var_20'], shade=True, color="g")
plt.title('var_20')
plt.xlabel('кол-во')
plt.ylabel('var_20')

plt.subplot(8,4,9)
sns.kdeplot(train_data['var_26'], shade=True, color="g")
plt.title('var_26')
plt.xlabel('кол-во')
plt.ylabel('var_26')

plt.subplot(8,4,10)
sns.kdeplot(train_data['var_40'], shade=True, color="g")
plt.title('var_40')
plt.xlabel('кол-во')
plt.ylabel('var_40')

plt.subplot(8,4,11)
sns.kdeplot(train_data['var_55'], shade=True, color="g")
plt.title('var_55')
plt.xlabel('кол-во')
plt.ylabel('var_55')

plt.subplot(8,4,12)
sns.kdeplot(train_data['var_80'], shade=True, color="g")
plt.title('var_80')
plt.xlabel('кол-во')
plt.ylabel('var_80')
# Out:
# Text(0, 0.5, 'var_80')

# %%
plt.figure(figsize = ([15,30]))

plt.subplots_adjust(wspace=0.4, hspace=0.35)

plt.subplot(8,4,1)
sns.kdeplot(test_data['var_0'], shade=True, color="g")
plt.title('var_0')
plt.xlabel('кол-во')
plt.ylabel('var_0')

plt.subplot(8,4,2)
sns.kdeplot(test_data['var_1'], shade=True, color="g")
plt.title('var_1')
plt.xlabel('кол-во')
plt.ylabel('var_1')

plt.subplot(8,4,3)
sns.kdeplot(test_data['var_2'], shade=True, color="g")
plt.title('var_2')
plt.xlabel('кол-во')
plt.ylabel('var_2')

plt.subplot(8,4,4)
sns.kdeplot(test_data['var_5'], shade=True, color="g")
plt.title('var_5')
plt.xlabel('кол-во')
plt.ylabel('var_5')

plt.subplot(8,4,5)
sns.kdeplot(test_data['var_9'], shade=True, color="g")
plt.title('var_9')
plt.xlabel('кол-во')
plt.ylabel('var_9')

plt.subplot(8,4,6)
sns.kdeplot(test_data['var_10'], shade=True, color="g")
plt.title('var_10')
plt.xlabel('кол-во')
plt.ylabel('var_10')

plt.subplot(8,4,7)
sns.kdeplot(test_data['var_13'], shade=True, color="g")
plt.title('var_13')
plt.xlabel('кол-во')
plt.ylabel('var_13')

plt.subplot(8,4,8)
sns.kdeplot(test_data['var_20'], shade=True, color="g")
plt.title('var_20')
plt.xlabel('кол-во')
plt.ylabel('var_20')

plt.subplot(8,4,9)
sns.kdeplot(test_data['var_26'], shade=True, color="g")
plt.title('var_26')
plt.xlabel('кол-во')
plt.ylabel('var_26')

plt.subplot(8,4,10)
sns.kdeplot(test_data['var_40'], shade=True, color="g")
plt.title('var_40')
plt.xlabel('кол-во')
plt.ylabel('var_40')

plt.subplot(8,4,11)
sns.kdeplot(test_data['var_55'], shade=True, color="g")
plt.title('var_55')
plt.xlabel('кол-во')
plt.ylabel('var_55')

plt.subplot(8,4,12)
sns.kdeplot(test_data['var_80'], shade=True, color="g")
plt.title('var_80')
plt.xlabel('кол-во')
plt.ylabel('var_80')
# Out:
# Text(0, 0.5, 'var_80')

# %%
# рассмотрим насколько аналогичны распределения в тренировочной и тестовой выборке
# вывод: данные близки по распределениюю имеют схожие параметры

name_col = ['var_0', 'var_1', 'var_2', 'var_5', 'var_9', 'var_10', 'var_13', 'var_20', 'var_26', 'var_40', 
            'var_55', 'var_80', 'var_106', 'var_109', 'var_139', 'var_175', 'var_184', 'var_196']

plt.figure(figsize = ([25,30]))


for n, m in enumerate(name_col, 1):
    plt.subplot(6,4,n)
    sns.kdeplot(train_data[m],alpha=0.5,label= m, color='blue', linewidth = 3)
    sns.kdeplot(test_data[m],alpha=0.5,label= m, color='r', linewidth = 3)
